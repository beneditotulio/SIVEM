# %% [markdown]
# # Exploração dos Dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

dataset = pd.read_csv('../data/raw/dados_de_incidentes_manifestacoes_mocambique(2024).csv')

dataset.head()
# Out:
#           period     country      province       phase    stage  \
# 0  21-25/10/2024  Mozambique  Cabo Delgado  1 - 2 Fase      NaN
# 1     15/11/2024  Mozambique  Cabo Delgado      4 Fase  1 Etapa
# 2  16-17/11/2024  Mozambique  Cabo Delgado      4 Fase  1 Etapa
# 3     18/11/2024  Mozambique  Cabo Delgado      4 Fase  1 Etapa
# 4  19-20/11/2024  Mozambique  Cabo Delgado      4 Fase  2 Etapa
#
#    registered_cases incident_type
# 0                16     Detencoes
# 1                 1     Detencoes
# 2                 0     Detencoes
# 3                 0     Detencoes
# 4                 0     Detencoes
